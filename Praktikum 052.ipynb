# %%
from pycaret.datasets import get_data
from pycaret.regression import *
from sklearn.model_selection import train_test_split
import pandas_profiling as pp
import pandas as pd
import numpy as np

# %%
df = get_data(dataset = 'index')
df
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
df = get_data(dataset = 'diamond', profile=True)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-11-18 08:15:53.262815&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df = df.dropna()
df = df.drop_duplicates()
df
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...

# %%
train, test = train_test_split(df, test_size=0.1, random_state=42, shuffle=True)

# %%
dataset = setup(data = train, target = 'Price', normalize = True, preprocess = True)
# Out:
# <style type="text/css">
# #T_37157_row10_col1, #T_37157_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_37157">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37157_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_37157_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37157_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37157_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_37157_row0_col1" class="data row0 col1" >6290</td>
#     </tr>
#     <tr>
#       <th id="T_37157_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37157_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_37157_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_37157_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(exclude = ['lightgbm'])

# %%
tuned_best = tune_model(estimator = best)
# Out:
# <style type="text/css">
# #T_ac5a6_row10_col0, #T_ac5a6_row10_col1, #T_ac5a6_row10_col2, #T_ac5a6_row10_col3, #T_ac5a6_row10_col4, #T_ac5a6_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ac5a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac5a6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ac5a6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ac5a6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ac5a6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ac5a6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ac5a6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
predictions = predict_model(tuned_best, data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_abaa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abaa4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_abaa4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_abaa4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_abaa4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_abaa4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_abaa4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_abaa4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abaa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abaa4_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_abaa4_row0_col1" class="data row0 col1" >614.8398</td>
# ...

# %%
predictions
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 1540          0.75            Ideal     D     VS2     ID       ID   AGSL
# 2315          0.90        Very Good     H     VS1     EX       VG    GIA
# 1198          1.08        Very Good     H     VS1     EX       EX    GIA
# 5115          1.01        Very Good     G     VS1     EX       EX    GIA
# 5653          0.80            Ideal     D     SI1     VG       VG    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 4556          0.93             Good     I     VS2      G        G    GIA
# 1195          1.21  Signature-Ideal     E    VVS2     ID       ID   AGSL
# 2253          0.78        Very Good     F     SI1     VG       VG    GIA
# 2773          1.56        Very Good     H     VS1     EX       EX    GIA
# 5069          1.27             Good     E     VS1     VG       VG    GIA
#
#       Price  prediction_label
# 1540   3679       3994.993698
# ...

# %%
evaluate_model(tuned_best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
interpret_model(tuned_best)

# %%
data = [[1.5, 'Signature-Ideal', 'H', 'SI1','ID', 'G', 'AGSL']]
tst = pd.DataFrame (data, columns= ['Carat Weight', 'Cut', 'Color', 'Clarity', 'Polish', 'Symmetry', 'Report'])
tst
# Out:
#    Carat Weight              Cut Color Clarity Polish Symmetry Report
# 0           1.5  Signature-Ideal     H     SI1     ID        G   AGSL

# %%
pred = predict_model(tuned_best, data=tst)

# %%
pred
# Out:
#    Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0           1.5  Signature-Ideal     H     SI1     ID        G   AGSL
#
#    prediction_label
# 0      11337.316958
